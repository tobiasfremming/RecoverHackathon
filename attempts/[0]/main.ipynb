# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
train = pd.read_csv("../../data/train.csv")

# %%
train.head()

# %%
# Create a dataframe with input columns
def create_training_data(df: pd.DataFrame) -> pd.DataFrame:
    pass
